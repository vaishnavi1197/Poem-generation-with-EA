# %%
import nltk
from nltk import pos_tag
import re

# %%
# creating an empty list
lst = []
 
# number of elements as input
n = int(input("Enter number of elements : "))
 
# iterating till the range
for i in range(0, n):
    ele = int(input())
 
    lst.append(ele) # adding the element
     
print(lst)
# Out:
# [1, 2, 3]

# %%
a = "afbabacbabia"
# a = "fiooifgh"
l = []
f_length = 0
f_result = 0

for j,i in enumerate(a):
    temp = a[j+1:]
    print("temp",temp)
    if i in temp:
        for m,n in enumerate(temp):
            if n == i:
                l.append(m)
        print("l",l) 
        l = sorted(l) 
        while(len(l)>0):      
            l_max = l.pop()
            print("l_max",l_max)
            p,q = j,l_max+j+2
            new = a[j:q]
            print("new",new)
            p = 1
            q = len(new)-1
            print("q",q)
            print(new[q:])
            while p-1<q:
                temp1 = new[:p]
                temp2 = new[q:]
                print("temp1,temp2",temp1,temp2)
                if temp1 != temp2[::-1]:
                    break
                else:
                    p = p+1
                    q = q-1
                    print("p,q",p,q)
            if temp1 == temp2[::-1]:
                if len(new)%2 != 0:
                    if a[p-1] == new[q:q+1]:
                        temp1 = temp1[:len(temp1)] + a[p-1]
                else:
                    pass
                result = temp1 + temp2
                length = len(result)
                print("f_length",f_length)
                if f_length < length:
                    f_result = result
                    f_length = len(f_result)
                print("f_result",f_result)
                print("result",result)
print("result",f_result)
print("============================")
# Out:
# temp fbabacbabia
# l [2, 4, 7, 10]
# l_max 10
# new afbabacbabia
# q 11
# a
# temp1,temp2 a a
# p,q 2 10
# temp1,temp2 af ia
# l_max 7
# new afbabacba
# q 8
# a
# temp1,temp2 a a
# p,q 2 7
# temp1,temp2 af ba
# l_max 4
# new afbaba
# q 5
# a
# temp1,temp2 a a
# p,q 2 4
# temp1,temp2 af ba
# l_max 2
# new afba
# q 3
# a
# temp1,temp2 a a
# p,q 2 2
# temp1,temp2 af ba
# temp babacbabia
# temp abacbabia
# l [1, 4, 6]
# l_max 6
# new babacbab
# q 7
# b
# temp1,temp2 b b
# p,q 2 6
# temp1,temp2 ba ab
# p,q 3 5
# temp1,temp2 bab bab
# p,q 4 4
# temp1,temp2 baba cbab
# l_max 4
# new babacb
# q 5
# b
# temp1,temp2 b b
# p,q 2 4
# temp1,temp2 ba cb
# l_max 1
# new bab
# q 2
# b
# temp1,temp2 b b
# p,q 2 1
# f_length 0
# f_result bb
# result bb
# temp bacbabia
# l [1, 4, 7]
# l_max 7
# new abacbabia
# q 8
# a
# temp1,temp2 a a
# p,q 2 7
# temp1,temp2 ab ia
# l_max 4
# new abacba
# q 5
# a
# temp1,temp2 a a
# p,q 2 4
# temp1,temp2 ab ba
# p,q 3 3
# temp1,temp2 aba cba
# l_max 1
# new aba
# q 2
# a
# temp1,temp2 a a
# p,q 2 1
# f_length 2
# f_result bb
# result aa
# temp acbabia
# l [2, 4]
# l_max 4
# new bacbab
# q 5
# b
# temp1,temp2 b b
# p,q 2 4
# temp1,temp2 ba ab
# p,q 3 3
# temp1,temp2 bac bab
# l_max 2
# new bacb
# q 3
# b
# temp1,temp2 b b
# p,q 2 2
# temp1,temp2 ba cb
# temp cbabia
# l [2, 5]
# l_max 5
# new acbabia
# q 6
# a
# temp1,temp2 a a
# p,q 2 5
# temp1,temp2 ac ia
# l_max 2
# new acba
# q 3
# a
# temp1,temp2 a a
# p,q 2 2
# temp1,temp2 ac ba
# temp babia
# temp abia
# l [1]
# l_max 1
# new bab
# q 2
# b
# temp1,temp2 b b
# p,q 2 1
# f_length 2
# f_result bb
# result bb
# temp bia
# l [2]
# l_max 2
# new abia
# q 3
# a
# temp1,temp2 a a
# p,q 2 2
# temp1,temp2 ab ia
# temp ia
# temp a
# temp
# result bb
# ============================

# %% [markdown]
# babababab

# %%
nltk.download('averaged_perceptron_tagger')

# %%
a = "asdf"
a[3:]
# Out:
# 'f'
